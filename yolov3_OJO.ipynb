# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/yolov3_OJO/darknet
# Out:
# /content/gdrive/MyDrive/yolov3_1/darknet

# %%
# Clone to get darknet Model
#!git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 14648 (delta 0), reused 0 (delta 0), pack-reused 14645
# Receiving objects: 100% (14648/14648), 13.24 MiB | 7.01 MiB/s, done.
# Resolving deltas: 100% (9969/9969), done.
# Checking out files: 100% (2027/2027), done.
# device(type='cpu')

# %%
# Configure MakeFile
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# Make a copy of yolov3.cfg
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# Change lines in yolov3.cfg file
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=8/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 8000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=4@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=4@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=4@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=27@' cfg/yolov3_training.cfg #(class+5)*3
# !sed -i '689 s@filters=255@filters=27@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=27@' cfg/yolov3_training.cfg

# %%
# !echo -e 'Handgun\nKnife\nRifle\nHuman_face' > data/obj.names
# !echo -e 'classes= 4\n train  = data/train.txt\n   valid=data/test.txt\n   names = data/obj.names\n backup=/content/gdrive/MyDrive/yolov3_1/weights' > data/obj.data

# %%
# !cp cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3_1/yolov3_training.cfg
# !cp data/obj.names /content/gdrive/MyDrive/yolov3_1/classes.txt

# %%
# !mkdir data/obj 

#!cp -r /content/gdrive/MyDrive/yolov3New/Dataset/validation /content/gdrive/MyDrive/yolov3New/darknet/data/obj/Dataset/validation
#!cp -r /content/gdrive/MyDrive/yolov3New/Dataset/train /content/gdrive/MyDrive/yolov3New/darknet/data/obj/Dataset/train
#!cp -r /content/gdrive/MyDrive/yolov4/darknet/data/obj/Dataset /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset
# Out:
# ^C

# %%
# !rm -r /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled
# !rm -r /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/input

# !unzip /content/gdrive/MyDrive/Datasets/input.zip -d /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train
# !unzip /content/gdrive/MyDrive/Datasets/CustomLabeled.zip -d /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/91e397ccef327cfdd.txt
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/91f4798d6c82cb077.txt
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/91f7c4835ce513a68.jpg
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/956959690dcc511a.txt
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/98eca605430fa574.txt
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/a10cac2d722241d3a.jpg
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/a121fdd16fd2ba97e.jpg
#   inflating: /content/gdrive/MyDrive/yolov3_1/darknet/data/obj/Dataset/train/CustomLabeled/a1269d51075f79c66.jpg
# ...

# %%
import glob
images_list = glob.glob("data/obj/Dataset/train/**/*.jpg")
print(len(images_list))
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

images_list = glob.glob("data/obj/Dataset/validation/**/*.jpg")
print(len(images_list))
with open("data/test.txt", "w") as f:
    f.write("\n".join(images_list))
# Out:
# 11824
# 240

# %%
#!wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-12-21 22:29:23--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  6.32MB/s    in 27s
#
# 2020-12-21 22:29:50 (5.70 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !sudo chmod +x darknet

# %%
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3_1/weights/yolov3_training_last.weights -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# yolov3_training
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 8, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !./darknet detector map data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3_1/weights/yolov3_training_last.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

imShow('chart.png')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# valid: Using default 'data/train.txt'
# names: Using default 'data/names.list'
# Couldn't open file: data/names.list

# %%
./darknet detector recall cfg/obj.data cfg/yolov3_training.cfg results/yolov3_training_final.weights

# %%
./darknet detector map cfg/obj.data cfg/yolov3_training.cfg results/yolov3_training_final.weights
